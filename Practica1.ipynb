# %% [markdown]
# <a href="https://colab.research.google.com/github/kimberlyhinoztrozaolg/unidad-2/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 2
# 03/octubre/ 2025
# ¿Que es pandas en Python? Pandas es una libreria o biblioteca de Python que se utiliza para trabajar con conjuntos de datos.
# Tiene funciones para analizar, limpiar, explorar y manipular datos.
# El nombre "Pandas" hace referencia a Panel data y
# Python data.
# Fue creado en el 2008.
# ¿Por qué utilizar pandas?
# Panda nos permite Analizar Big Data y y sacar conclusiones basadas en teorías,estadísticas.Los pandas
# pueden limpiar conjuntos de datos desordenados y hacerlos legibles y relevantes. Los datos relevantes son muy importantes en la ciencia de datus.
# ¿Qué pódemos hacer con pandas?
# 1. Saber si existe corrélación entre dos o más columnas
# 2. Cuáto es el valor promedio
# 3. Valor máximo
# 4. Valor minimo
# Pandas también puede eliminar filas que no son relevantes o que contienen errores, como valores vacíos. Esto se llama limpieza de datos.
# Instalación de Pandas
# Si tienes python y pip ya instalado en un
# sistema, instalalo usando el siguiente comando pip install pandas.
# Si este comando falla, utiliza una distribución de python que ya tenga pandas instalado.
# Importar Pandas
# Unci vez instalado pandas importalo a tus aplicaciones agregando la palabra clave
# Import Pandas.
# Ahora pandas esta importado y listo para usar.
# Panda como pd  crea un alias con la palabra as al importar pandas.
# Ejemplo:

# %%
import pandas as pd

# %% [markdown]
# Ahora el paquete pandas puede denominarse pd en lugar de pandas.
# Comprobando la versión de Pandas.
# La cadena de la versión se almacena en el atributo_Versión_
# Ejemplo :

# %%
import pandas as pd
print(pd.__version__)

# %% [markdown]
# Ejercicio:
# biblioteca oficial
# ¿Cual de las Siguientes 3 opciones es la biblioteca oficial de Pandas?
# 1. Import p
# 2. Import pandas
# 3. Import pan
# Pandas serie
# ¿Qué es una serie?
# Una serie Pandas es como una columna en una tabla
# Es una matriz unidimensional que contiene datos de cualquier tipo.
# Ejemplo:

# %%
import pandas as pd
arreglo=[1,7,2]
myvar=pd Series(a)
print(myvar)

# %% [markdown]
# Etiquetas
# Sino se específica nada más, los valores se etiquetan con su número de indice, el primer valor tiene el indice 0, el segundo valor tiene índice 1,etc.
# Esta etiqueta se puede utilizar para acceder a un valor especifico.
# ejemplo:
# devuelve el primer valor de la serie.

# %%
print(myvar[0])

# %% [markdown]
# Crear etiquetas
# Con el argumento index, podemos nombrar nuestras propias etiquetas.
# ejemplo:
# Crea tus propias etiquetas.

# %%
myvar=pd. serie (arreglo, index =["x","y","Z"])
print(myvar)

# %% [markdown]
# Cuando hayamos creado etiquetas, podemos acceder a un elemento haciendo  referencia a su etiqueta.
# Ejemplo:
# Devuelve el valor de y

# %%
print(myvar["y"])

# %% [markdown]
# Objetos clave/valor como serie.
# También podemos utilizar un objeto clave: valor como un diccionario, al crear una serie.
# Ejemplo:
# Crea una serie Pandas básica a partir de un diccionario.

# %%
import pandas as pd
calories = {"day1": 420, "day2": 380, "day3": 340}
myvar=pd.Series(calories, index=["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# Nota: Las claves del diccionario se convierten en las etiquetas.
# Para seleccionar elementos del diccionario utilice el argumento. index y específique el elemento que desea intruir en la serie
# Ejemplo:
# Crea una serie utilizando unicamente datos de día 1 y dico 2.

# %%
myvar = pd.series(calorías, index["dia1", "dia2"])
print(myvar)

# %% [markdown]
# Data Frame.
# Marcos de datas.
# Los conjuntos de datos en pandas suelen ser tablas multidimensionales llamadas data Frames. La serie es como una columnas un data frame es toda la tabla
# Ejemplo:
# crea un data frame a partir de dos series.
# ¿Una serie es como un renglon en una tabla
# Falso, es como una columna

# %%
import pandas as pd
data = {
  "calories": [420,380,390],
  "duration": [50,40,45]
}
myvar=pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
